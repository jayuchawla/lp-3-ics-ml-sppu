# %%
import matplotlib.pyplot as plt

x_points = [0.1,0.15,0.08,0.16,0.2,0.25,0.24,0.3]
y_points = [0.6,0.71,0.9,0.85,0.3,0.5,0.1,0.2]

# %%
def euclideanDistance(point, x, y):
    print(point, x, y)
    return math.sqrt(((point[0]-x)**2) + ((point[1]-y)**2))
    

def returnCluster(m1,m2,x,y):
    dist1 = euclideanDistance(m1,x,y)
    dist2 = euclideanDistance(m2,x,y)
    print(dist1,dist2)
    
    if dist1<dist2:
        return 1
    elif dist1>=dist2:
        return 2

m1 = [0.1,0.6]
m2 = [0.3,0.2]

difference = float('inf')
threshold = 0.02

cluster1 = []
cluster2 = []

while difference > threshold:
    print(m1)
    print(m2)
    
    cluster1 = []
    cluster2 = []

    for i in range(len(x_points)):
        clusterNumber = returnCluster(m1, m2, x_points[i], y_points[i])
        point = [x_points[i], y_points[i]]

        if clusterNumber == 1:
            cluster1.append(point)
        else:
            cluster2.append(point)
        
    x1 = [x[0] for x in cluster1]
    y1 = [x[1] for x in cluster1]

    x2 = [x[0] for x in cluster2]
    y2 = [x[1] for x in cluster2]

    xSum = 0.0
    ySum = 0.0
    for i in range(len(cluster1)):
        xSum += cluster1[i][0]
        ySum += cluster1[i][1]
    
    xSum = xSum/len(cluster1)
    ySum = ySum/len(cluster1)
    
    
    m1old = m1
    m1=[]
    m1 = [xSum,ySum]
    
    xSum = 0.0
    ySum = 0.0
    for i in range(len(cluster2)):
        xSum += cluster2[i][0]
        ySum += cluster2[i][1]
    
    xSum = xSum/len(cluster2)
    ySum = ySum/len(cluster2)
    
    
    m2old = m2
    m2 = []
    m2 = [xSum,ySum]
   
    xAvg = 0.0
    yAvg = 0.0
    
    xAvg = math.fabs(m2[0]-m2old[0])+ math.fabs(m1[0]-m1old[0])
    xAvg = xAvg / 2
    
    yAvg = math.fabs(m2[1]-m2old[1])+ math.fabs(m1[1]-m1old[1])
    yAvg = yAvg/2
    
    if xAvg>yAvg:
        difference = xAvg
    else:
        difference=yAvg
        
    print('difference = ', difference)
# Out:
# [0.1, 0.6]
# [0.3, 0.2]
# ([0.1, 0.6], 0.1, 0.6)
# ([0.3, 0.2], 0.1, 0.6)
# (0.0, 0.44721359549995787)
# ([0.1, 0.6], 0.15, 0.71)
# ([0.3, 0.2], 0.15, 0.71)
# (0.12083045973594571, 0.5316013544000805)
# ([0.1, 0.6], 0.08, 0.9)
# ([0.3, 0.2], 0.08, 0.9)
# (0.3006659275674582, 0.7337574531137656)
# ([0.1, 0.6], 0.16, 0.85)
# ([0.3, 0.2], 0.16, 0.85)
# (0.2570992026436488, 0.6649060083951716)
# ([0.1, 0.6], 0.2, 0.3)
# ([0.3, 0.2], 0.2, 0.3)
# (0.31622776601683794, 0.14142135623730948)
# ([0.1, 0.6], 0.25, 0.5)
# ([0.3, 0.2], 0.25, 0.5)
# (0.18027756377319945, 0.30413812651491096)
# ([0.1, 0.6], 0.24, 0.1)
# ([0.3, 0.2], 0.24, 0.1)
# (0.5192301994298868, 0.11661903789690602)
# ([0.1, 0.6], 0.3, 0.2)
# ([0.3, 0.2], 0.3, 0.2)
# (0.44721359549995787, 0.0)
# ('difference = ', 0.05600000000000001)
# [0.148, 0.712]
# [0.24666666666666667, 0.20000000000000004]
# ([0.148, 0.712], 0.1, 0.6)
# ([0.24666666666666667, 0.20000000000000004], 0.1, 0.6)
# (0.12185236969382252, 0.4260412082312121)
# ([0.148, 0.712], 0.15, 0.71)
# ([0.24666666666666667, 0.20000000000000004], 0.15, 0.71)
# (0.0028284271247461927, 0.5190803834132478)
# ([0.148, 0.712], 0.08, 0.9)
# ([0.24666666666666667, 0.20000000000000004], 0.08, 0.9)
# (0.19991998399359684, 0.71956777149743)
# ([0.148, 0.712], 0.16, 0.85)
# ([0.24666666666666667, 0.20000000000000004], 0.16, 0.85)
# (0.13852075656738236, 0.6557523245182674)
# ([0.148, 0.712], 0.2, 0.3)
# ([0.24666666666666667, 0.20000000000000004], 0.2, 0.3)
# (0.4152685877838583, 0.11035296904831228)
# ([0.148, 0.712], 0.25, 0.5)
# ([0.24666666666666667, 0.20000000000000004], 0.25, 0.5)
# (0.235261556570554, 0.3000185179469945)
# ([0.148, 0.712], 0.24, 0.1)
# ([0.24666666666666667, 0.20000000000000004], 0.24, 0.1)
# (0.618876401230488, 0.10022197585581942)
# ([0.148, 0.712], 0.3, 0.2)
# ([0.24666666666666667, 0.20000000000000004], 0.3, 0.2)
# (0.5340861353751846, 0.053333333333333316)
# ('difference = ', 0.0)

# %%
print(m1)
print(m2)

print(cluster1)
print(cluster2)
x1 = [x[0] for x in cluster1]
y1 = [x[1] for x in cluster1]

plt.plot(x1,y1,'ro')

x2 = [x[0] for x in cluster2]
y2 = [x[1] for x in cluster2]

plt.plot(x2,y2,'g^')

plt.show()
# Out:
# [0.148, 0.712]
# [0.24666666666666667, 0.20000000000000004]
# [[0.1, 0.6], [0.15, 0.71], [0.08, 0.9], [0.16, 0.85], [0.25, 0.5]]
# [[0.2, 0.3], [0.24, 0.1], [0.3, 0.2]]
